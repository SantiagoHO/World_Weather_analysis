# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 765

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=54f095e24ee79064b3f6428afecadea2

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City" : city.title(), "Country" : city_country,
                         "Lat" : city_lat, "lng" : city_lng,
                         "Max Temp" : city_max_temp, "Humidity" : city_humidity,
                         "Cloudiness" : city_clouds, "wind Speed" : city_wind,
                         "Description" : city_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | oranjemund
# Processing Record 2 of Set 1 | mount isa
# Processing Record 3 of Set 1 | inuvik
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | klaksvik
# Processing Record 6 of Set 1 | geraldton
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | katsuura
# Processing Record 10 of Set 1 | longyearbyen
# Processing Record 11 of Set 1 | sao raimundo nonato
# Processing Record 12 of Set 1 | lompoc
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | carnarvon
# Processing Record 15 of Set 1 | krasnoye-na-volge
# Processing Record 16 of Set 1 | pinega
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | saint george
# Processing Record 19 of Set 1 | boende
# Processing Record 20 of Set 1 | batagay
# Processing Record 21 of Set 1 | dumas
# Processing Record 22 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | vardo
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | ojinaga
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | seymchan
# Processing Record 33 of Set 1 | itacare
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 1 | dingle
# Processing Record 39 of Set 1 | matara
# Processing Record 40 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 1 | kincardine
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | mahebourg
# Processing Record 44 of Set 1 | bixby
# Processing Record 45 of Set 1 | beroroha
# Processing Record 46 of Set 1 | viseu
# Processing Record 47 of Set 1 | port lincoln
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | clarence town
# Processing Record 1 of Set 2 | maniitsoq
# Processing Record 2 of Set 2 | urucui
# Processing Record 3 of Set 2 | tura
# Processing Record 4 of Set 2 | atkarsk
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | taltal
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | nikolskoye
# Processing Record 12 of Set 2 | juifang
# City not found. Skipping...
# Processing Record 13 of Set 2 | skjervoy
# Processing Record 14 of Set 2 | hervey bay
# Processing Record 15 of Set 2 | taft
# Processing Record 16 of Set 2 | belmonte
# Processing Record 17 of Set 2 | puerto ayacucho
# Processing Record 18 of Set 2 | buraydah
# Processing Record 19 of Set 2 | pevek
# Processing Record 20 of Set 2 | aligudarz
# Processing Record 21 of Set 2 | victor harbor
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | evensk
# Processing Record 24 of Set 2 | nyurba
# Processing Record 25 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 2 | ostrovnoy
# Processing Record 27 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 2 | sambava
# Processing Record 29 of Set 2 | pontianak
# Processing Record 30 of Set 2 | saskylakh
# Processing Record 31 of Set 2 | fort dix
# Processing Record 32 of Set 2 | ponta do sol
# Processing Record 33 of Set 2 | izumo
# Processing Record 34 of Set 2 | florianopolis
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | palmer
# Processing Record 37 of Set 2 | san vicente
# Processing Record 38 of Set 2 | sao filipe
# Processing Record 39 of Set 2 | norman wells
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | acapulco
# Processing Record 42 of Set 2 | svetlogorsk
# Processing Record 43 of Set 2 | dikson
# Processing Record 44 of Set 2 | lorengau
# Processing Record 45 of Set 2 | martapura
# Processing Record 46 of Set 2 | codrington
# Processing Record 47 of Set 2 | dunedin
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | cherskiy
# Processing Record 50 of Set 2 | yumen
# Processing Record 1 of Set 3 | aklavik
# Processing Record 2 of Set 3 | namalenga
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | mpwapwa
# Processing Record 7 of Set 3 | chokurdakh
# Processing Record 8 of Set 3 | lagoa
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | coahuayana
# Processing Record 11 of Set 3 | kostino
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | praia da vitoria
# Processing Record 14 of Set 3 | saldanha
# Processing Record 15 of Set 3 | nhulunbuy
# Processing Record 16 of Set 3 | katangli
# Processing Record 17 of Set 3 | jamestown
# Processing Record 18 of Set 3 | mandalgovi
# Processing Record 19 of Set 3 | serpa
# Processing Record 20 of Set 3 | comodoro rivadavia
# Processing Record 21 of Set 3 | paddhari
# Processing Record 22 of Set 3 | leningradskiy
# Processing Record 23 of Set 3 | qibili
# City not found. Skipping...
# Processing Record 24 of Set 3 | aden
# Processing Record 25 of Set 3 | okhotsk
# Processing Record 26 of Set 3 | srednekolymsk
# Processing Record 27 of Set 3 | ankara
# Processing Record 28 of Set 3 | eskil
# Processing Record 29 of Set 3 | sarankhola
# Processing Record 30 of Set 3 | porto novo
# Processing Record 31 of Set 3 | clyde river
# Processing Record 32 of Set 3 | indramayu
# Processing Record 33 of Set 3 | saint-francois
# Processing Record 34 of Set 3 | arraial do cabo
# Processing Record 35 of Set 3 | muros
# Processing Record 36 of Set 3 | ancud
# Processing Record 37 of Set 3 | lavrentiya
# Processing Record 38 of Set 3 | bredasdorp
# Processing Record 39 of Set 3 | iquitos
# Processing Record 40 of Set 3 | cullera
# Processing Record 41 of Set 3 | los llanos de aridane
# Processing Record 42 of Set 3 | hami
# Processing Record 43 of Set 3 | kilgore
# Processing Record 44 of Set 3 | nome
# Processing Record 45 of Set 3 | inirida
# Processing Record 46 of Set 3 | hofn
# Processing Record 47 of Set 3 | bethel
# Processing Record 48 of Set 3 | nanortalik
# Processing Record 49 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 3 | tasiilaq
# Processing Record 1 of Set 4 | yellowknife
# Processing Record 2 of Set 4 | vestmannaeyjar
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | currais novos
# Processing Record 5 of Set 4 | placido de castro
# Processing Record 6 of Set 4 | buala
# Processing Record 7 of Set 4 | guilin
# Processing Record 8 of Set 4 | san rafael
# Processing Record 9 of Set 4 | bac lieu
# Processing Record 10 of Set 4 | waingapu
# Processing Record 11 of Set 4 | bambanglipuro
# Processing Record 12 of Set 4 | severo-kurilsk
# Processing Record 13 of Set 4 | kapaa
# Processing Record 14 of Set 4 | baikunthpur
# Processing Record 15 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 4 | satun
# Processing Record 17 of Set 4 | boyolangu
# Processing Record 18 of Set 4 | tignere
# Processing Record 19 of Set 4 | paamiut
# Processing Record 20 of Set 4 | chuy
# Processing Record 21 of Set 4 | pokhara
# Processing Record 22 of Set 4 | dawlatabad
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | kaitangata
# Processing Record 25 of Set 4 | santa maria
# Processing Record 26 of Set 4 | kurilsk
# Processing Record 27 of Set 4 | port hedland
# Processing Record 28 of Set 4 | kahului
# Processing Record 29 of Set 4 | freeport
# Processing Record 30 of Set 4 | north bend
# Processing Record 31 of Set 4 | russell
# Processing Record 32 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 4 | te anau
# Processing Record 34 of Set 4 | osnabruck
# Processing Record 35 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 4 | hobyo
# Processing Record 37 of Set 4 | tomatlan
# Processing Record 38 of Set 4 | renfrew
# Processing Record 39 of Set 4 | faya
# Processing Record 40 of Set 4 | ust-kulom
# Processing Record 41 of Set 4 | lesozavodsk
# Processing Record 42 of Set 4 | upernavik
# Processing Record 43 of Set 4 | itoman
# Processing Record 44 of Set 4 | shizuishan
# Processing Record 45 of Set 4 | inhambane
# Processing Record 46 of Set 4 | mareeba
# Processing Record 47 of Set 4 | sungurlare
# Processing Record 48 of Set 4 | klaeng
# Processing Record 49 of Set 4 | kawalu
# Processing Record 50 of Set 4 | grand gaube
# Processing Record 1 of Set 5 | flin flon
# Processing Record 2 of Set 5 | jieshi
# Processing Record 3 of Set 5 | limbang
# Processing Record 4 of Set 5 | urulga
# City not found. Skipping...
# Processing Record 5 of Set 5 | yining
# Processing Record 6 of Set 5 | sainte-marie
# Processing Record 7 of Set 5 | barira
# Processing Record 8 of Set 5 | ilulissat
# Processing Record 9 of Set 5 | asau
# Processing Record 10 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 5 | pekalongan
# Processing Record 12 of Set 5 | yulara
# Processing Record 13 of Set 5 | ulagan
# Processing Record 14 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 5 | vila velha
# Processing Record 16 of Set 5 | iqaluit
# Processing Record 17 of Set 5 | westonaria
# Processing Record 18 of Set 5 | namibe
# Processing Record 19 of Set 5 | livingston
# Processing Record 20 of Set 5 | talnakh
# Processing Record 21 of Set 5 | lander
# Processing Record 22 of Set 5 | cabo san lucas
# Processing Record 23 of Set 5 | ahuimanu
# Processing Record 24 of Set 5 | san isidro
# Processing Record 25 of Set 5 | aldan
# Processing Record 26 of Set 5 | mahenge
# Processing Record 27 of Set 5 | san ramon
# Processing Record 28 of Set 5 | tiksi
# Processing Record 29 of Set 5 | kaliua
# Processing Record 30 of Set 5 | sur
# Processing Record 31 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 5 | georgetown
# Processing Record 33 of Set 5 | namatanai
# Processing Record 34 of Set 5 | agadir
# Processing Record 35 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 36 of Set 5 | stade
# Processing Record 37 of Set 5 | kalevala
# Processing Record 38 of Set 5 | lamar
# Processing Record 39 of Set 5 | port blair
# Processing Record 40 of Set 5 | yerbogachen
# Processing Record 41 of Set 5 | bengkulu
# Processing Record 42 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 5 | manokwari
# Processing Record 44 of Set 5 | anadyr
# Processing Record 45 of Set 5 | qasigiannguit
# Processing Record 46 of Set 5 | sabha
# Processing Record 47 of Set 5 | zhangye
# Processing Record 48 of Set 5 | tual
# Processing Record 49 of Set 5 | labuhan
# Processing Record 50 of Set 5 | barranca
# Processing Record 1 of Set 6 | sinnamary
# Processing Record 2 of Set 6 | qaanaaq
# Processing Record 3 of Set 6 | hasaki
# Processing Record 4 of Set 6 | jimbolia
# Processing Record 5 of Set 6 | aberdeen
# Processing Record 6 of Set 6 | bathsheba
# Processing Record 7 of Set 6 | kandrian
# Processing Record 8 of Set 6 | hithadhoo
# Processing Record 9 of Set 6 | luderitz
# Processing Record 10 of Set 6 | guangyuan
# Processing Record 11 of Set 6 | la palma
# Processing Record 12 of Set 6 | atikokan
# Processing Record 13 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 6 | tiarei
# Processing Record 15 of Set 6 | ambilobe
# Processing Record 16 of Set 6 | blythe
# Processing Record 17 of Set 6 | half moon bay
# Processing Record 18 of Set 6 | ghanzi
# Processing Record 19 of Set 6 | sobolevo
# Processing Record 20 of Set 6 | lasa
# Processing Record 21 of Set 6 | huambo
# Processing Record 22 of Set 6 | orapa
# Processing Record 23 of Set 6 | cidreira
# Processing Record 24 of Set 6 | goderich
# Processing Record 25 of Set 6 | san patricio
# Processing Record 26 of Set 6 | khatanga
# Processing Record 27 of Set 6 | adrar
# Processing Record 28 of Set 6 | morehead
# Processing Record 29 of Set 6 | altamont
# Processing Record 30 of Set 6 | kununurra
# Processing Record 31 of Set 6 | pangnirtung
# Processing Record 32 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 6 | lebu
# Processing Record 34 of Set 6 | taruma
# Processing Record 35 of Set 6 | marawi
# Processing Record 36 of Set 6 | richards bay
# Processing Record 37 of Set 6 | hay river
# Processing Record 38 of Set 6 | vostok
# Processing Record 39 of Set 6 | chandrapur
# Processing Record 40 of Set 6 | ouesso
# Processing Record 41 of Set 6 | provost
# Processing Record 42 of Set 6 | sitka
# Processing Record 43 of Set 6 | ibra
# Processing Record 44 of Set 6 | tsentralnyy
# City not found. Skipping...
# Processing Record 45 of Set 6 | kavieng
# Processing Record 46 of Set 6 | denpasar
# Processing Record 47 of Set 6 | kristiinankaupunki
# Processing Record 48 of Set 6 | fuerte olimpo
# Processing Record 49 of Set 6 | thompson
# Processing Record 50 of Set 6 | mogadishu
# Processing Record 1 of Set 7 | deputatskiy
# Processing Record 2 of Set 7 | oromocto
# Processing Record 3 of Set 7 | west wendover
# Processing Record 4 of Set 7 | banjarmasin
# Processing Record 5 of Set 7 | barcelos
# Processing Record 6 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 7 | udala
# Processing Record 8 of Set 7 | del rio
# Processing Record 9 of Set 7 | ewa beach
# Processing Record 10 of Set 7 | shelburne
# Processing Record 11 of Set 7 | sangin
# Processing Record 12 of Set 7 | cananea
# Processing Record 13 of Set 7 | misratah
# Processing Record 14 of Set 7 | waipawa
# Processing Record 15 of Set 7 | provideniya
# Processing Record 16 of Set 7 | altay
# Processing Record 17 of Set 7 | teguldet
# Processing Record 18 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 19 of Set 7 | ormara
# Processing Record 20 of Set 7 | huarmey
# Processing Record 21 of Set 7 | wagar
# Processing Record 22 of Set 7 | marzuq
# Processing Record 23 of Set 7 | ust-nera
# Processing Record 24 of Set 7 | airai
# Processing Record 25 of Set 7 | sechura
# Processing Record 26 of Set 7 | mount pleasant
# Processing Record 27 of Set 7 | cherat
# Processing Record 28 of Set 7 | darhan
# Processing Record 29 of Set 7 | kidal
# Processing Record 30 of Set 7 | kurchum
# Processing Record 31 of Set 7 | pacific grove
# Processing Record 32 of Set 7 | ito
# Processing Record 33 of Set 7 | esperance
# Processing Record 34 of Set 7 | port said
# Processing Record 35 of Set 7 | severnyy
# Processing Record 36 of Set 7 | andarab
# City not found. Skipping...
# Processing Record 37 of Set 7 | vaxjo
# Processing Record 38 of Set 7 | darnah
# Processing Record 39 of Set 7 | maicao
# Processing Record 40 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 7 | singkawang
# Processing Record 42 of Set 7 | salalah
# Processing Record 43 of Set 7 | black river
# Processing Record 44 of Set 7 | iaciara
# Processing Record 45 of Set 7 | beringovskiy
# Processing Record 46 of Set 7 | garm
# City not found. Skipping...
# Processing Record 47 of Set 7 | vestmanna
# Processing Record 48 of Set 7 | fallon
# Processing Record 49 of Set 7 | waw
# Processing Record 50 of Set 7 | kenitra
# Processing Record 1 of Set 8 | upata
# Processing Record 2 of Set 8 | nokaneng
# Processing Record 3 of Set 8 | astoria
# Processing Record 4 of Set 8 | hualmay
# Processing Record 5 of Set 8 | coquimbo
# Processing Record 6 of Set 8 | high level
# Processing Record 7 of Set 8 | prince albert
# Processing Record 8 of Set 8 | dalvik
# Processing Record 9 of Set 8 | qaqortoq
# Processing Record 10 of Set 8 | broome
# Processing Record 11 of Set 8 | quatre cocos
# Processing Record 12 of Set 8 | ternate
# Processing Record 13 of Set 8 | okakarara
# Processing Record 14 of Set 8 | lata
# Processing Record 15 of Set 8 | vanavara
# Processing Record 16 of Set 8 | milkovo
# Processing Record 17 of Set 8 | olovyannaya
# Processing Record 18 of Set 8 | jalu
# Processing Record 19 of Set 8 | guane
# Processing Record 20 of Set 8 | mayachnyy
# Processing Record 21 of Set 8 | tsukumi
# Processing Record 22 of Set 8 | hurghada
# Processing Record 23 of Set 8 | wichita falls
# Processing Record 24 of Set 8 | senanga
# Processing Record 25 of Set 8 | caravelas
# Processing Record 26 of Set 8 | mana
# Processing Record 27 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 28 of Set 8 | bartica
# Processing Record 29 of Set 8 | seydi
# Processing Record 30 of Set 8 | synya
# Processing Record 31 of Set 8 | toma
# Processing Record 32 of Set 8 | antofagasta
# Processing Record 33 of Set 8 | hakkari
# Processing Record 34 of Set 8 | bloemfontein
# Processing Record 35 of Set 8 | gornyy
# Processing Record 36 of Set 8 | utete
# Processing Record 37 of Set 8 | nabire
# Processing Record 38 of Set 8 | pakxe
# Processing Record 39 of Set 8 | glenwood springs
# Processing Record 40 of Set 8 | talcahuano
# Processing Record 41 of Set 8 | tzucacab
# Processing Record 42 of Set 8 | zhanaozen
# Processing Record 43 of Set 8 | san joaquin
# Processing Record 44 of Set 8 | zemio
# Processing Record 45 of Set 8 | tuljapur
# Processing Record 46 of Set 8 | uruzgan
# Processing Record 47 of Set 8 | aushiger
# Processing Record 48 of Set 8 | crestview
# Processing Record 49 of Set 8 | mehamn
# Processing Record 50 of Set 8 | sao joao da barra
# Processing Record 1 of Set 9 | bay roberts
# Processing Record 2 of Set 9 | koumac
# Processing Record 3 of Set 9 | portland
# Processing Record 4 of Set 9 | talaya
# Processing Record 5 of Set 9 | sijunjung
# Processing Record 6 of Set 9 | vao
# Processing Record 7 of Set 9 | san felipe
# Processing Record 8 of Set 9 | golaghat
# Processing Record 9 of Set 9 | morrope
# Processing Record 10 of Set 9 | sakakah
# Processing Record 11 of Set 9 | huadian
# Processing Record 12 of Set 9 | northam
# Processing Record 13 of Set 9 | tezu
# Processing Record 14 of Set 9 | coihaique
# Processing Record 15 of Set 9 | outlook
# Processing Record 16 of Set 9 | pangody
# Processing Record 17 of Set 9 | uvalde
# Processing Record 18 of Set 9 | sibolga
# Processing Record 19 of Set 9 | samrala
# Processing Record 20 of Set 9 | hare bay
# Processing Record 21 of Set 9 | klamath falls
# Processing Record 22 of Set 9 | narsaq
# Processing Record 23 of Set 9 | sorland
# Processing Record 24 of Set 9 | nemuro
# Processing Record 25 of Set 9 | visby
# Processing Record 26 of Set 9 | trjavna
# City not found. Skipping...
# Processing Record 27 of Set 9 | new norfolk
# Processing Record 28 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 9 | san ramon de la nueva oran
# Processing Record 30 of Set 9 | koundara
# Processing Record 31 of Set 9 | margate
# Processing Record 32 of Set 9 | muisne
# Processing Record 33 of Set 9 | paiho
# City not found. Skipping...
# Processing Record 34 of Set 9 | kongolo
# Processing Record 35 of Set 9 | sandakan
# Processing Record 36 of Set 9 | groa
# Processing Record 37 of Set 9 | port hardy
# Processing Record 38 of Set 9 | olafsvik
# Processing Record 39 of Set 9 | santa pola
# Processing Record 40 of Set 9 | nkowakowa
# Processing Record 41 of Set 9 | horconcitos
# Processing Record 42 of Set 9 | alofi
# Processing Record 43 of Set 9 | houma
# Processing Record 44 of Set 9 | villarrica
# Processing Record 45 of Set 9 | souillac
# Processing Record 46 of Set 9 | umm kaddadah
# Processing Record 47 of Set 9 | yichang
# Processing Record 48 of Set 9 | verkhnyaya inta
# Processing Record 49 of Set 9 | chumikan
# Processing Record 50 of Set 9 | nampula
# Processing Record 1 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 2 of Set 10 | capacuaro
# Processing Record 3 of Set 10 | karakol
# Processing Record 4 of Set 10 | kristiansund
# Processing Record 5 of Set 10 | coos bay
# Processing Record 6 of Set 10 | viedma
# Processing Record 7 of Set 10 | gilbues
# Processing Record 8 of Set 10 | caceres
# Processing Record 9 of Set 10 | terney
# Processing Record 10 of Set 10 | vanderhoof
# Processing Record 11 of Set 10 | dalaoig
# Processing Record 12 of Set 10 | fethiye
# Processing Record 13 of Set 10 | nouadhibou
# Processing Record 14 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 16 of Set 10 | ayutla
# Processing Record 17 of Set 10 | itarema
# Processing Record 18 of Set 10 | valparaiso
# Processing Record 19 of Set 10 | north battleford
# Processing Record 20 of Set 10 | goksun
# Processing Record 21 of Set 10 | guarapari
# Processing Record 22 of Set 10 | saint-georges
# Processing Record 23 of Set 10 | ulladulla
# Processing Record 24 of Set 10 | coffs harbour
# Processing Record 25 of Set 10 | chadan
# Processing Record 26 of Set 10 | elko
# Processing Record 27 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 10 | hatillo
# Processing Record 29 of Set 10 | komsomolskiy
# Processing Record 30 of Set 10 | bulnes
# Processing Record 31 of Set 10 | the valley
# Processing Record 32 of Set 10 | novobiryusinskiy
# Processing Record 33 of Set 10 | amapa
# Processing Record 34 of Set 10 | linchuan
# City not found. Skipping...
# Processing Record 35 of Set 10 | christchurch
# Processing Record 36 of Set 10 | wabana
# Processing Record 37 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 10 | ranong
# Processing Record 39 of Set 10 | vanimo
# Processing Record 40 of Set 10 | pascagoula
# Processing Record 41 of Set 10 | ampanihy
# Processing Record 42 of Set 10 | chirongui
# Processing Record 43 of Set 10 | goya
# Processing Record 44 of Set 10 | teneguiban
# City not found. Skipping...
# Processing Record 45 of Set 10 | chuguyevka
# Processing Record 46 of Set 10 | chernyshevskiy
# Processing Record 47 of Set 10 | sawakin
# Processing Record 48 of Set 10 | gat
# Processing Record 49 of Set 10 | malanville
# Processing Record 50 of Set 10 | xuddur
# Processing Record 1 of Set 11 | curanilahue
# Processing Record 2 of Set 11 | torit
# Processing Record 3 of Set 11 | davila
# Processing Record 4 of Set 11 | kropotkin
# Processing Record 5 of Set 11 | chicama
# Processing Record 6 of Set 11 | kayes
# Processing Record 7 of Set 11 | samarai
# Processing Record 8 of Set 11 | karwar
# Processing Record 9 of Set 11 | sassandra
# Processing Record 10 of Set 11 | palmas
# Processing Record 11 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 11 | hoquiam
# Processing Record 13 of Set 11 | potsdam
# Processing Record 14 of Set 11 | meulaboh
# Processing Record 15 of Set 11 | college
# Processing Record 16 of Set 11 | anloga
# Processing Record 17 of Set 11 | mackay
# Processing Record 18 of Set 11 | halifax
# Processing Record 19 of Set 11 | takoradi
# Processing Record 20 of Set 11 | assiniboia
# Processing Record 21 of Set 11 | harlingen
# Processing Record 22 of Set 11 | qatana
# Processing Record 23 of Set 11 | monrovia
# Processing Record 24 of Set 11 | mpika
# Processing Record 25 of Set 11 | jertih
# Processing Record 26 of Set 11 | nuuk
# Processing Record 27 of Set 11 | la ronge
# Processing Record 28 of Set 11 | mabaruma
# Processing Record 29 of Set 11 | gravdal
# Processing Record 30 of Set 11 | rio cuarto
# Processing Record 31 of Set 11 | piet retief
# Processing Record 32 of Set 11 | pavlovsk
# Processing Record 33 of Set 11 | fortuna
# Processing Record 34 of Set 11 | yeniseysk
# Processing Record 35 of Set 11 | xiamen
# Processing Record 36 of Set 11 | yaan
# Processing Record 37 of Set 11 | waddan
# Processing Record 38 of Set 11 | maningrida
# Processing Record 39 of Set 11 | vung tau
# Processing Record 40 of Set 11 | putyatino
# Processing Record 41 of Set 11 | tabou
# Processing Record 42 of Set 11 | guerrero negro
# Processing Record 43 of Set 11 | san juan
# Processing Record 44 of Set 11 | ugoofaaru
# Processing Record 45 of Set 11 | suntar
# Processing Record 46 of Set 11 | san carlos de bariloche
# Processing Record 47 of Set 11 | dibulla
# Processing Record 48 of Set 11 | hagere selam
# Processing Record 49 of Set 11 | avera
# Processing Record 50 of Set 11 | boa vista
# Processing Record 1 of Set 12 | niksic
# Processing Record 2 of Set 12 | okha
# Processing Record 3 of Set 12 | serra talhada
# Processing Record 4 of Set 12 | tuatapere
# Processing Record 5 of Set 12 | shitkino
# Processing Record 6 of Set 12 | bubaque
# Processing Record 7 of Set 12 | dubrovka
# Processing Record 8 of Set 12 | kamaishi
# Processing Record 9 of Set 12 | wana
# Processing Record 10 of Set 12 | den helder
# Processing Record 11 of Set 12 | tongren
# Processing Record 12 of Set 12 | pisco
# Processing Record 13 of Set 12 | fara in sabina
# Processing Record 14 of Set 12 | monatele
# City not found. Skipping...
# Processing Record 15 of Set 12 | trat
# Processing Record 16 of Set 12 | chadiza
# Processing Record 17 of Set 12 | dalby
# Processing Record 18 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 19 of Set 12 | limburg
# Processing Record 20 of Set 12 | byron bay
# Processing Record 21 of Set 12 | hohhot
# Processing Record 22 of Set 12 | cabra
# Processing Record 23 of Set 12 | fort nelson
# Processing Record 24 of Set 12 | nazca
# Processing Record 25 of Set 12 | troitskoye
# Processing Record 26 of Set 12 | honningsvag
# Processing Record 27 of Set 12 | conakry
# Processing Record 28 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 12 | vermilion
# Processing Record 30 of Set 12 | palu
# Processing Record 31 of Set 12 | gizo
# Processing Record 32 of Set 12 | chingirlau
# Processing Record 33 of Set 12 | berlevag
# Processing Record 34 of Set 12 | pilar
# Processing Record 35 of Set 12 | ahipara
# Processing Record 36 of Set 12 | kijang
# Processing Record 37 of Set 12 | pithoragarh
# Processing Record 38 of Set 12 | sitrah
# Processing Record 39 of Set 12 | kuah
# Processing Record 40 of Set 12 | emerald
# Processing Record 41 of Set 12 | kemise
# Processing Record 42 of Set 12 | matagami
# Processing Record 43 of Set 12 | dayong
# Processing Record 44 of Set 12 | gamba
# Processing Record 45 of Set 12 | masuguru
# Processing Record 46 of Set 12 | shache
# Processing Record 47 of Set 12 | montague
# Processing Record 48 of Set 12 | la asuncion
# Processing Record 49 of Set 12 | tome-acu
# City not found. Skipping...
# Processing Record 50 of Set 12 | zakamensk
# Processing Record 1 of Set 13 | yuanping
# Processing Record 2 of Set 13 | brownsville
# Processing Record 3 of Set 13 | laguna
# Processing Record 4 of Set 13 | ilek
# Processing Record 5 of Set 13 | kruisfontein
# Processing Record 6 of Set 13 | leh
# Processing Record 7 of Set 13 | birnin kebbi
# Processing Record 8 of Set 13 | umm lajj
# Processing Record 9 of Set 13 | mongoumba
# Processing Record 10 of Set 13 | micheweni
# Processing Record 11 of Set 13 | sept-iles
# Processing Record 12 of Set 13 | white oak
# Processing Record 13 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 13 | olivenza
# Processing Record 15 of Set 13 | binzhou
# Processing Record 16 of Set 13 | izhma
# Processing Record 17 of Set 13 | kabare
# Processing Record 18 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 13 | kibre mengist
# Processing Record 20 of Set 13 | mount gambier
# Processing Record 21 of Set 13 | yar-sale
# Processing Record 22 of Set 13 | awbari
# Processing Record 23 of Set 13 | kuala pilah
# Processing Record 24 of Set 13 | zalantun
# Processing Record 25 of Set 13 | wenling
# Processing Record 26 of Set 13 | marathon
# Processing Record 27 of Set 13 | san pedro de ycuamandiyu
# Processing Record 28 of Set 13 | sioux lookout
# Processing Record 29 of Set 13 | remontnoye
# Processing Record 30 of Set 13 | rocha
# Processing Record 31 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 32 of Set 13 | bandarbeyla
# Processing Record 33 of Set 13 | urengoy
# Processing Record 34 of Set 13 | loreto
# Processing Record 35 of Set 13 | mapiripan
# Processing Record 36 of Set 13 | rio gallegos
# Processing Record 37 of Set 13 | williams lake
# Processing Record 38 of Set 13 | buta
# Processing Record 39 of Set 13 | bayir
# Processing Record 40 of Set 13 | yamada
# Processing Record 41 of Set 13 | purranque
# Processing Record 42 of Set 13 | isangel
# Processing Record 43 of Set 13 | pangoa
# Processing Record 44 of Set 13 | banjar
# Processing Record 45 of Set 13 | mbuyapey
# Processing Record 46 of Set 13 | cayenne
# Processing Record 47 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 13 | west bay
# Processing Record 49 of Set 13 | hauterive
# Processing Record 50 of Set 13 | tiverton
# Processing Record 1 of Set 14 | kiama
# Processing Record 2 of Set 14 | panzhihua
# Processing Record 3 of Set 14 | makakilo city
# Processing Record 4 of Set 14 | saryagash
# Processing Record 5 of Set 14 | heihe
# Processing Record 6 of Set 14 | moussoro
# Processing Record 7 of Set 14 | tautira
# Processing Record 8 of Set 14 | jodhpur
# Processing Record 9 of Set 14 | poum
# Processing Record 10 of Set 14 | puerto baquerizo moreno
# Processing Record 11 of Set 14 | vertientes
# Processing Record 12 of Set 14 | frankfort
# Processing Record 13 of Set 14 | culebra
# Processing Record 14 of Set 14 | punta cardon
# Processing Record 15 of Set 14 | kota bahru
# Processing Record 16 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 14 | lucera
# Processing Record 18 of Set 14 | pouebo
# Processing Record 19 of Set 14 | road town
# Processing Record 20 of Set 14 | sale
# Processing Record 21 of Set 14 | sembe
# Processing Record 22 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 23 of Set 14 | bajo baudo
# City not found. Skipping...
# Processing Record 24 of Set 14 | gobabis
# Processing Record 25 of Set 14 | gornopravdinsk
# Processing Record 26 of Set 14 | aguimes
# Processing Record 27 of Set 14 | taksimo
# Processing Record 28 of Set 14 | isla vista
# Processing Record 29 of Set 14 | georgiyevka
# Processing Record 30 of Set 14 | saint-denis
# Processing Record 31 of Set 14 | beloha
# Processing Record 32 of Set 14 | robore
# Processing Record 33 of Set 14 | esmeraldas
# Processing Record 34 of Set 14 | blackwater
# Processing Record 35 of Set 14 | strathmore
# Processing Record 36 of Set 14 | mega
# Processing Record 37 of Set 14 | ilhabela
# Processing Record 38 of Set 14 | shubarshi
# Processing Record 39 of Set 14 | conceicao da barra
# Processing Record 40 of Set 14 | virginia beach
# Processing Record 41 of Set 14 | touros
# Processing Record 42 of Set 14 | cap-aux-meules
# Processing Record 43 of Set 14 | zalaszentgrot
# Processing Record 44 of Set 14 | vila do maio
# Processing Record 45 of Set 14 | udachnyy
# Processing Record 46 of Set 14 | wagga wagga
# Processing Record 47 of Set 14 | orlik
# Processing Record 48 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 49 of Set 14 | adre
# Processing Record 50 of Set 14 | mbaiki
# Processing Record 1 of Set 15 | pak phanang
# Processing Record 2 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 15 | tarazona
# Processing Record 4 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 15 | chara
# Processing Record 6 of Set 15 | uk
# City not found. Skipping...
# Processing Record 7 of Set 15 | ordzhonikidze
# Processing Record 8 of Set 15 | sarkand
# Processing Record 9 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 10 of Set 15 | zwedru
# Processing Record 11 of Set 15 | chengde
# Processing Record 12 of Set 15 | port-gentil
# Processing Record 13 of Set 15 | gourdon
# Processing Record 14 of Set 15 | mao
# Processing Record 15 of Set 15 | grindavik
# Processing Record 16 of Set 15 | santa marta
# Processing Record 17 of Set 15 | diu
# Processing Record 18 of Set 15 | port macquarie
# Processing Record 19 of Set 15 | bonthe
# Processing Record 20 of Set 15 | chambersburg
# Processing Record 21 of Set 15 | hermiston
# Processing Record 22 of Set 15 | talakan
# Processing Record 23 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 15 | bolshiye uki
# City not found. Skipping...
# Processing Record 25 of Set 15 | kachkanar
# Processing Record 26 of Set 15 | balkanabat
# Processing Record 27 of Set 15 | raudeberg
# Processing Record 28 of Set 15 | cassilandia
# Processing Record 29 of Set 15 | minna
# Processing Record 30 of Set 15 | heswall
# Processing Record 31 of Set 15 | mankono
# Processing Record 32 of Set 15 | waverley
# Processing Record 33 of Set 15 | challans
# Processing Record 34 of Set 15 | erzurum
# Processing Record 35 of Set 15 | borcea
# Processing Record 36 of Set 15 | abnub
# Processing Record 37 of Set 15 | jawhar
# Processing Record 38 of Set 15 | ferme-neuve
# Processing Record 39 of Set 15 | ilheus
# Processing Record 40 of Set 15 | khor
# Processing Record 41 of Set 15 | majene
# Processing Record 42 of Set 15 | santa isabel
# Processing Record 43 of Set 15 | akyab
# Processing Record 44 of Set 15 | nizwa
# Processing Record 45 of Set 15 | acarau
# Processing Record 46 of Set 15 | banyo
# Processing Record 47 of Set 15 | semporna
# Processing Record 48 of Set 15 | iberia
# Processing Record 49 of Set 15 | benjamin constant
# Processing Record 50 of Set 15 | launceston
# Processing Record 1 of Set 16 | taraz
# Processing Record 2 of Set 16 | liverpool
# Processing Record 3 of Set 16 | ilam
# Processing Record 4 of Set 16 | biltine
# Processing Record 5 of Set 16 | batamshinskiy
# Processing Record 6 of Set 16 | aykino
# Processing Record 7 of Set 16 | san cristobal
# Processing Record 8 of Set 16 | nishihara
# Processing Record 9 of Set 16 | khormuj
# City not found. Skipping...
# Processing Record 10 of Set 16 | nicoya
# Processing Record 11 of Set 16 | ocampo
# Processing Record 12 of Set 16 | morondava
# Processing Record 13 of Set 16 | ucluelet
# Processing Record 14 of Set 16 | porto nacional
# Processing Record 15 of Set 16 | karratha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 706

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 0    Oranjemund      NA -28.5500   16.4333     60.44        86          52
# 1     Mount Isa      AU -20.7333  139.5000     92.97        22          42
# 2        Inuvik      CA  68.3499 -133.7218     -1.34        78          20
# 3  Punta Arenas      CL -53.1500  -70.9167     42.91        81          75
# 4      Klaksvik      FO  62.2266   -6.5890     45.52        93          68
# 5     Geraldton      AU -28.7667  114.6000     75.61        41           0
# 6      Hermanus      ZA -34.4187   19.2345     55.80        74         100
# 7     Busselton      AU -33.6500  115.3333     73.44        41           2
# 8      Katsuura      JP  35.1333  140.3000     66.22        55           5
# 9  Longyearbyen      SJ  78.2186   15.6401     12.04        62          75
#
#    wind Speed       Description
# 0       14.81     broken clouds
# 1        5.75  scattered clouds
# 2        5.75        few clouds
# 3        9.22     broken clouds
# 4       22.86     broken clouds
# 5       16.11         clear sky
# 6        6.20   overcast clouds
# 7       12.50         clear sky
# 8       25.46         clear sky
# 9        9.22     broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'wind Speed', 'Description'],
#       dtype='object')

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_csv = "./WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_csv, index_label = "City_ID")
